# %% [markdown]
# # clinical

# %%
import pandas as pd

# %%
df = pd.read_csv('/Data_hackathon/Clinical/TCGA-LUAD_clinical.tsv.gz', compression='gzip', sep='\t')

# %%
pd.set_option('display.max_rows', 500)

# %%
df['high_grade'].value_counts(dropna=False)
# Out:
# Non-advanced    486
# Advanced         37
# NaN               9
# Name: high_grade, dtype: int64

# %%
df[df['high_grade'].isna()].T
# Out:
#                                                                                                36   \
# barcode                                                               TCGA-50-5045-01A-01R-1628-07
# sample                                                                            TCGA-50-5045-01A
# patient                                                                               TCGA-50-5045
# TSS                                                                                             50
# center                                                                                           7
# high_grade                                                                                     NaN
# definition                                                                     Primary solid Tumor
# Purety_CCF                                                                                  0.4327
# ...

# %%
df['ajcc_pathologic_stage'].value_counts(dropna=False)
# Out:
# Stage IB      151
# Stage IA      137
# Stage IIB      73
# Stage IIIA     66
# Stage IIA      53
# Stage IV       28
# NaN             9
# Stage IIIB      9
# Stage I         5
# Stage II        1
# Name: ajcc_pathologic_stage, dtype: int64

# %%
df['patient'].value_counts(dropna=False)
# Out:
# TCGA-44-2668    4
# TCGA-44-2662    4
# TCGA-44-6146    4
# TCGA-44-5645    4
# TCGA-44-6147    4
# TCGA-44-3918    3
# TCGA-44-2656    3
# TCGA-44-2666    3
# TCGA-44-6775    3
# TCGA-55-6978    2
# TCGA-49-4490    2
# TCGA-55-6982    2
# TCGA-55-6968    2
# TCGA-38-4627    2
# TCGA-55-6975    2
# TCGA-38-4625    2
# TCGA-49-6745    2
# TCGA-55-6986    2
# TCGA-50-5066    2
# TCGA-49-6761    2
# TCGA-44-6145    2
# TCGA-55-6970    2
# TCGA-44-3398    2
# TCGA-55-6981    2
# TCGA-55-6983    2
# TCGA-50-5939    2
# TCGA-55-6980    2
# TCGA-44-6778    2
# TCGA-44-2665    2
# TCGA-44-3396    2
# TCGA-44-2655    2
# TCGA-73-4676    2
# TCGA-49-6744    2
# TCGA-38-4632    2
# TCGA-55-6985    2
# TCGA-44-6776    2
# TCGA-55-6979    2
# TCGA-44-6148    2
# TCGA-55-6972    2
# TCGA-44-6777    2
# TCGA-38-4626    2
# TCGA-44-3917    2
# TCGA-49-6742    2
# TCGA-55-6971    2
# TCGA-44-2657    2
# TCGA-50-5931    2
# TCGA-49-6743    2
# TCGA-49-4512    2
# TCGA-44-4112    2
# TCGA-55-6984    2
# ...

# %%
df.T
# Out:
#                                                                                                0    \
# barcode                                                               TCGA-78-8655-01A-11R-2403-07
# sample                                                                            TCGA-78-8655-01A
# patient                                                                               TCGA-78-8655
# TSS                                                                                             78
# center                                                                                           7
# high_grade                                                                            Non-advanced
# definition                                                                     Primary solid Tumor
# Purety_CCF                                                                                  0.6573
# ...

# %% [markdown]
# # other

# %%
pwd
# Out:
# '/workspace'

# %%
# !ln -s /Data_hackathon/ Data_hackathon

# %%
df = pd.read_csv('/Data_hackathon/Workflow_outputs/COAD/immune_pop_deconvolution/COAD_MCPcounter.tsv', sep='\t')
df
# Out:
#                  Signature  TCGA-D5-6530-01A-11R-1723-07  \
# 0                  T cells                      7.108418
# 1              CD8 T cells                      6.559942
# 2    Cytotoxic lymphocytes                      6.590262
# 3                B lineage                      7.727253
# 4                 NK cells                      5.591372
# 5        Monocytic lineage                      9.091506
# 6  Myeloid dendritic cells                      6.057260
# 7              Neutrophils                      7.753936
# 8        Endothelial cells                      7.729682
# 9              Fibroblasts                     12.020278
#
#    TCGA-G4-6320-01A-11R-1723-07  TCGA-AD-6888-01A-11R-1928-07  \
# 0                      6.391000                      5.713496
# 1                      5.061284                      6.256595
# 2                      5.830365                      4.829775
# 3                      8.036520                      5.900203
# ...

# %%
df = pd.read_csv('/Data_hackathon/Workflow_outputs/COAD/immune_pop_deconvolution/COAD_MCPcounter_scaled.tsv', sep='\t')
df
# Out:
#                  Signature  TCGA-D5-6530-01A-11R-1723-07  \
# 0                  T cells                      0.881710
# 1              CD8 T cells                     -0.001029
# 2    Cytotoxic lymphocytes                      1.186412
# 3                B lineage                      0.411476
# 4                 NK cells                      1.555203
# 5        Monocytic lineage                      1.011814
# 6  Myeloid dendritic cells                      0.103286
# 7              Neutrophils                      0.729073
# 8        Endothelial cells                     -0.707596
# 9              Fibroblasts                     -0.402280
#
#    TCGA-G4-6320-01A-11R-1723-07  TCGA-AD-6888-01A-11R-1928-07  \
# 0                     -0.360226                     -1.533068
# 1                     -1.533631                     -0.311247
# 2                      0.035886                     -1.479063
# 3                      0.661644                     -1.066439
# ...

# %%
df = pd.read_csv('/Data_hackathon/Workflow_outputs/COAD/diffexp/COAD_Advanced-vs-Non-advanced.diffexp.symbol.tsv', sep='\t')
df.head(30)
# Out:
#           gene     baseMean  log2FoldChange     lfcSE       stat  \
# 0          7SK  3344.448211       -4.908249  0.286374 -17.139283
# 1     SCARNA10    25.221553       -3.992298  0.305902 -13.050900
# 2      SCARNA7    35.061872       -3.272914  0.300394 -10.895408
# 3      SNORA12     8.868747       -3.265425  0.304048 -10.739820
# 4        SCN5A    29.686574        1.649043  0.158094  10.430746
# 5      SNORA53    16.110494       -2.199497  0.216161 -10.175284
# 6     MAPK6PS3     5.397231       -2.508923  0.267233  -9.388525
# 7        RPPH1     9.329408       -3.694736  0.395240  -9.348075
# 8     SCARNA21     7.845258       -2.523116  0.283171  -8.910216
# 9         UPK2    16.119639        2.153552  0.242299   8.887984
# 10       CCL25    45.858093       -2.525387  0.286809  -8.805114
# 11     RNU5E-1    23.196929       -3.545041  0.402422  -8.809251
# 12       FABP4    63.949126        1.779100  0.205884   8.641257
# ...
